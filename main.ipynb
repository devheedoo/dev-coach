# %%
from dotenv import load_dotenv
from dev_coach import graph

load_dotenv()

config = {"configurable": {"thread_id": "1"}}

graph.invoke(
    {
        "topic": "React performance",
        "profile": {
            "years_experience": 5,
            "role": "Frontend Engineer",
            "level": "Senior",
        },
    },
    config=config,
)
# Out:
# /Volumes/hdrive/dev/lab/dev-coach/.venv/lib/python3.13/site-packages/langgraph/cache/base/__init__.py:8: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer
# {'profile': {'years_experience': 5,
#   'role': 'Frontend Engineer',
#   'level': 'Senior'},
#  'topic': 'React performance',
#  'current_question': 'In a React application, what strategies would you employ to optimize performance when rendering a large list of items? Please discuss specific techniques, tools, and best practices you would consider.',
# ...
